# %%
import os
from dotenv import load_dotenv
load_dotenv()

from ingest import load_faq_data, build_index
from rag_helper import RAGBase
from openai import OpenAI

documents = load_faq_data()
index = build_index(documents)

openai_client = OpenAI(
    api_key=os.getenv("OLLAMA_API_KEY"),
    base_url="http://localhost:11434/v1"
)

assistant = RAGBase(
    index=index,
    llm_client=openai_client,
)

answer = assistant.rag("I just discovered the course. Can I join now?")
print(answer)
# Out:
# Yes, you can still join the course now.

# %%
assistant.rag("How do I get a certificate?")
# Out:
# "I don't know."

# %%
assistant.rag("Can I still join the course after it started?")
# Out:
# "I don't know. The context does not provide information about whether it's still possible to join the course after it started."
